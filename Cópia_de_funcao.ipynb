# %% [markdown]
# <a href="https://colab.research.google.com/github/LaianeNR/TechCorp-Brasil/blob/main/C%C3%B3pia_de_funcao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def gerar_dataframe(qtd=500_00, seed=42):

    np.random.seed(seed)

    id_funcionario = np.arange(1, qtd + 1)
    idade = np.random.randint(18, 60, size=qtd)
    genero = np.random.choice(['Masculino', 'Feminino', 'Prefiro não informar'], size=qtd, p=[0.45, 0.35, 0.20])
    estado_civil = np.random.choice(['Solteiro(a)', 'Casado(a)', 'Divorciado(a)', 'Prefiro não informar'], size=qtd)
    escolaridade = np.random.choice(['Ensino Médio', 'Graduação', 'Pós', 'Mestrado', 'Doutorado', 'Prefiro não informar'], size=qtd)
    cor_raca = np.random.choice(['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'Prefiro não informar'], size=qtd)
    filhos = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd)
    nacionalidade = np.random.choice(['Brasileira', 'Estrangeira', 'Prefiro não informar'], size=qtd)
    naturalidade = np.random.choice(['SP', 'RJ', 'MG', 'Outros', 'Prefiro não informar'], size=qtd)
    tipo_moradia = np.random.choice(['Alugada', 'Própria', 'Compartilhada', 'Prefiro não informar'], size=qtd)
    pcd = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.05, 0.95])
    estado_uf = np.random.choice(['SP', 'RJ', 'MG', 'BA', 'RS', 'CE', 'DF', 'PE', 'AM', 'MT', 'PR', 'AL', 'SC', ' ', 'Não informado'], size=qtd)

    area_formacao = np.random.choice([
        'Cientista de Dados/Data Scientist', 'Desenvolvedor', 'Engenharia de Software', 'Marketing',
        'RH', 'Product Manager/PO', 'Analista de Dados/Data Analyst', 'Administrativo', 'Financeiro',
        'Vendas', 'Pesquisa e Desenvolvimento', 'Engenharia de Dados/Data Engineer', 'UX/UI',
        'Suporte Técnico', 'Prefiro não informar'], size=qtd)

    departamento = np.random.choice(['Vendas', 'RH', 'TI', 'Pesquisa', 'Negócio', 'Administrativo'], size=qtd)
    cargo = np.random.choice([
        'Especialista', 'Gestor?', 'Cargo como Gestor', 'Tempo de experiência na área',
        'Gerente', 'Senior', 'Pleno', 'Junior', 'Estagiário', 'Prefiro não informar'], size=qtd)

    envolvimento = np.random.randint(1, 5, size=qtd)
    anos_empresa = np.random.randint(0, 41, size=qtd)
    promocoes = np.random.randint(0, 6, size=qtd)
    salario = np.random.randint(1500, 25000, size=qtd)
    faixa_salarial = pd.cut(salario, bins=[0, 3000, 7000, 12000, 18000, np.inf],
                            labels=['Muito baixa', 'Baixa', 'Média', 'Alta', 'Muito alta'])
    aumento = np.random.randint(0, 30, size=qtd)
    nivel_acao = np.random.randint(0, 4, size=qtd)

    sat_trabalho = np.random.randint(1, 6, size=qtd)
    sat_ambiente = np.random.randint(1, 6, size=qtd)
    sat_relacionamento = np.random.randint(1, 6, size=qtd)
    sat_beneficios = np.random.randint(1, 6, size=qtd)

    hora_extra = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.3, 0.7])
    equilibrio = np.random.randint(1, 5, size=qtd)
    viagem = np.random.choice(['Nunca', 'Raramente', 'Frequentemente'], size=qtd)
    distancia = np.random.randint(1, 50, size=qtd)
    avaliacao = np.random.choice([3, 4], size=qtd, p=[0.9, 0.1])
    treinamentos = np.random.randint(0, 6, size=qtd)

    pretende_mudar = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd, p=[0.3, 0.6, 0.1])
    futuro_empresa = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd)
    expectativa_crescimento = np.random.choice(['Alta', 'Média', 'Baixa', 'Prefiro não informar'], size=qtd)

    motivo_mudanca = np.random.choice(['Salário', 'Home Office', 'Ambiente de trabalho', 'Desenvolvimento profissional', 'Mudança de cidade', 'Não responder'], size=qtd)
    afastamentos = np.random.randint(0, 4, size=qtd)
    atestados = np.random.randint(0, 10, size=qtd)

    saiu_empresa = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.16, 0.84])
    saiu_empresa = pd.Categorical(saiu_empresa, categories=['Sim', 'Não'], ordered=True)

    df = pd.DataFrame({
        'ID Funcionário': id_funcionario,
        'Idade': idade,
        'Gênero': genero,
        'Estado Civil': estado_civil,
        'Escolaridade': escolaridade,
        'Cor/Raça': cor_raca,
        'Filhos': filhos,
        'Nacionalidade': nacionalidade,
        'Naturalidade': naturalidade,
        'Tipo de Moradia': tipo_moradia,
        'PCD': pcd,
        'Estado/UF': estado_uf,
        'Área de Formação': area_formacao,
        'Departamento': departamento,
        'Cargo': cargo,
        'Envolvimento no Trabalho': envolvimento,
        'Anos na Empresa': anos_empresa,
        'Número de Promoções': promocoes,
        'Salário Mensal': salario,
        'Faixa Salarial': faixa_salarial,
        'Aumento Salarial (%)': aumento,
        'Nível de Opção de Ação': nivel_acao,
        'Satisfação no Trabalho': sat_trabalho,
        'Satisfação com o Ambiente de Trabalho': sat_ambiente,
        'Satisfação com Relacionamento no Trabalho': sat_relacionamento,
        'Satisfação com os Benefícios': sat_beneficios,
        'Hora Extra': hora_extra,
        'Equilíbrio Vida-Trabalho': equilibrio,
        'Viagem a Negócios': viagem,
        'Distância Casa (km)': distancia,
        'Avaliação de Desempenho (1-5)': avaliacao,
        'Treinamentos por Ano': treinamentos,
        'Pretende Mudar de Emprego?': pretende_mudar,
        'Você se vê na empresa em 5 anos?': futuro_empresa,
        'Expectativa de Crescimento': expectativa_crescimento,
        'Motivo da Mudança de Emprego': motivo_mudanca,
        'Histórico de Afastamentos': afastamentos,
        'Número de Atestados': atestados,
        'Saiu da Empresa?': saiu_empresa
    })

    colunas_nulas = ['Salário Mensal', 'Área de Formação', 'Satisfação no Trabalho', 'Anos na Empresa']
    for coluna in colunas_nulas:
        qtd_nulo = int(qtd * 0.05)
        indices_nulo = np.random.choice(df.index, qtd_nulo, replace=False)
        df.loc[indices_nulo, coluna] = np.nan

    colunas_numericas = [
        'Salário Mensal', 'Anos na Empresa', 'Idade', 'Envolvimento no Trabalho',
        'Aumento Salarial (%)', 'Nível de Opção de Ação', 'Satisfação no Trabalho',
        'Satisfação com o Ambiente de Trabalho', 'Satisfação com Relacionamento no Trabalho',
        'Equilíbrio Vida-Trabalho', 'Distância Casa (km)', 'Avaliação de Desempenho (1-5)',
        'Treinamentos por Ano'
    ]
    for coluna in colunas_numericas:
        qtd_neg = int(qtd * 0.01)
        indices_neg = np.random.choice(df.index, qtd_neg, replace=False)
        df.loc[indices_neg, coluna] *= -1

    variacoes = {
        'Desenvolvedor': ['Desenvolvedor ', 'Dev', 'desenvolvedor'],
        'Cientista de Dados/Data Scientist': ['Cientista de Dados', 'Data Scientist', 'DS']
    }
    for original, alteracoes in variacoes.items():
        indices = df[df['Área de Formação'] == original].sample(frac=0.1, replace=False, random_state=seed).index
        if not indices.empty:
            df.loc[indices, 'Área de Formação'] = np.random.choice(alteracoes, size=len(indices))

    indices_uf = df.sample(frac=0.005, replace=False, random_state=seed).index
    df.loc[indices_uf, 'Estado/UF'] = 'XX'

    indices_outlier_salario = df.sample(frac=0.001, replace=False, random_state=seed).index
    df.loc[indices_outlier_salario, 'Salário Mensal'] = np.random.randint(50000, 100000, size=len(indices_outlier_salario))


    jovens = df[df['Idade'] < 30]
    indices_jovens = jovens.sample(frac=0.001, replace=False, random_state=seed).index
    df.loc[indices_jovens, 'Anos na Empresa'] = df.loc[indices_jovens, 'Idade'] + np.random.randint(5, 15, size=len(indices_jovens))


    indices_cargo = df.sample(frac=0.005, replace=False, random_state=seed).index
    indices_validos = indices_cargo[df.loc[indices_cargo, 'Anos na Empresa'].notna() & (df.loc[indices_cargo, 'Anos na Empresa'] >= 0)]
    df.loc[indices_validos, 'Cargo'] = 'Tempo: ' + (df.loc[indices_validos, 'Anos na Empresa'] + np.random.randint(1, 5, size=len(indices_validos))).astype(str)

    return df

# %%
df_funcionarios = gerar_dataframe(qtd=500_00, seed=42)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def gerar_dataframe(qtd=500_00, seed=42):

    np.random.seed(seed)

    id_funcionario = np.arange(1, qtd + 1)
    idade = np.random.randint(18, 60, size=qtd)
    genero = np.random.choice(['Masculino', 'Feminino', 'Prefiro não informar'], size=qtd, p=[0.45, 0.35, 0.20])
    estado_civil = np.random.choice(['Solteiro(a)', 'Casado(a)', 'Divorciado(a)', 'Prefiro não informar'], size=qtd)
    escolaridade = np.random.choice(['Ensino Médio', 'Graduação', 'Pós', 'Mestrado', 'Doutorado', 'Prefiro não informar'], size=qtd)
    cor_raca = np.random.choice(['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'Prefiro não informar'], size=qtd)
    filhos = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd)
    nacionalidade = np.random.choice(['Brasileira', 'Estrangeira', 'Prefiro não informar'], size=qtd)
    naturalidade = np.random.choice(['SP', 'RJ', 'MG', 'Outros', 'Prefiro não informar'], size=qtd)
    tipo_moradia = np.random.choice(['Alugada', 'Própria', 'Compartilhada', 'Prefiro não informar'], size=qtd)
    pcd = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.05, 0.95])
    estado_uf = np.random.choice(['SP', 'RJ', 'MG', 'BA', 'RS', 'CE', 'DF', 'PE', 'AM', 'MT', 'PR', 'AL', 'SC', ' ', 'Não informado'], size=qtd)

    area_formacao = np.random.choice([
        'Cientista de Dados/Data Scientist', 'Desenvolvedor', 'Engenharia de Software', 'Marketing',
        'RH', 'Product Manager/PO', 'Analista de Dados/Data Analyst', 'Administrativo', 'Financeiro',
        'Vendas', 'Pesquisa e Desenvolvimento', 'Engenharia de Dados/Data Engineer', 'UX/UI',
        'Suporte Técnico', 'Prefiro não informar'], size=qtd)

    departamento = np.random.choice(['Vendas', 'RH', 'TI', 'Pesquisa', 'Negócio', 'Administrativo'], size=qtd)
    cargo = np.random.choice([
        'Especialista', 'Gestor?', 'Cargo como Gestor', 'Tempo de experiência na área',
        'Gerente', 'Senior', 'Pleno', 'Junior', 'Estagiário', 'Prefiro não informar'], size=qtd)

    envolvimento = np.random.randint(1, 5, size=qtd)
    anos_empresa = np.random.randint(0, 41, size=qtd)
    promocoes = np.random.randint(0, 6, size=qtd)
    salario = np.random.randint(1500, 25000, size=qtd)
    faixa_salarial = pd.cut(salario, bins=[0, 3000, 7000, 12000, 18000, np.inf],
                            labels=['Muito baixa', 'Baixa', 'Média', 'Alta', 'Muito alta'])
    aumento = np.random.randint(0, 30, size=qtd)
    nivel_acao = np.random.randint(0, 4, size=qtd)

    sat_trabalho = np.random.randint(1, 6, size=qtd)
    sat_ambiente = np.random.randint(1, 6, size=qtd)
    sat_relacionamento = np.random.randint(1, 6, size=qtd)
    sat_beneficios = np.random.randint(1, 6, size=qtd)

    hora_extra = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.3, 0.7])
    equilibrio = np.random.randint(1, 5, size=qtd)
    viagem = np.random.choice(['Nunca', 'Raramente', 'Frequentemente'], size=qtd)
    distancia = np.random.randint(1, 50, size=qtd)
    avaliacao = np.random.choice([3, 4], size=qtd, p=[0.9, 0.1])
    treinamentos = np.random.randint(0, 6, size=qtd)

    pretende_mudar = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd, p=[0.3, 0.6, 0.1])
    futuro_empresa = np.random.choice(['Sim', 'Não', 'Prefiro não informar'], size=qtd)
    expectativa_crescimento = np.random.choice(['Alta', 'Média', 'Baixa', 'Prefiro não informar'], size=qtd)

    motivo_mudanca = np.random.choice(['Salário', 'Home Office', 'Ambiente de trabalho', 'Desenvolvimento profissional', 'Mudança de cidade', 'Não responder'], size=qtd)
    afastamentos = np.random.randint(0, 4, size=qtd)
    atestados = np.random.randint(0, 10, size=qtd)

    saiu_empresa = np.random.choice(['Sim', 'Não'], size=qtd, p=[0.16, 0.84])
    saiu_empresa = pd.Categorical(saiu_empresa, categories=['Sim', 'Não'], ordered=True)

    df = pd.DataFrame({
        'ID Funcionário': id_funcionario,
        'Idade': idade,
        'Gênero': genero,
        'Estado Civil': estado_civil,
        'Escolaridade': escolaridade,
        'Cor/Raça': cor_raca,
        'Filhos': filhos,
        'Nacionalidade': nacionalidade,
        'Naturalidade': naturalidade,
        'Tipo de Moradia': tipo_moradia,
        'PCD': pcd,
        'Estado/UF': estado_uf,
        'Área de Formação': area_formacao,
        'Departamento': departamento,
        'Cargo': cargo,
        'Envolvimento no Trabalho': envolvimento,
        'Anos na Empresa': anos_empresa,
        'Número de Promoções': promocoes,
        'Salário Mensal': salario,
        'Faixa Salarial': faixa_salarial,
        'Aumento Salarial (%)': aumento,
        'Nível de Opção de Ação': nivel_acao,
        'Satisfação no Trabalho': sat_trabalho,
        'Satisfação com o Ambiente de Trabalho': sat_ambiente,
        'Satisfação com Relacionamento no Trabalho': sat_relacionamento,
        'Satisfação com os Benefícios': sat_beneficios,
        'Hora Extra': hora_extra,
        'Equilíbrio Vida-Trabalho': equilibrio,
        'Viagem a Negócios': viagem,
        'Distância Casa (km)': distancia,
        'Avaliação de Desempenho (1-5)': avaliacao,
        'Treinamentos por Ano': treinamentos,
        'Pretende Mudar de Emprego?': pretende_mudar,
        'Você se vê na empresa em 5 anos?': futuro_empresa,
        'Expectativa de Crescimento': expectativa_crescimento,
        'Motivo da Mudança de Emprego': motivo_mudanca,
        'Histórico de Afastamentos': afastamentos,
        'Número de Atestados': atestados,
        'Saiu da Empresa?': saiu_empresa
    })

    colunas_nulas = ['Salário Mensal', 'Área de Formação', 'Satisfação no Trabalho', 'Anos na Empresa']
    for coluna in colunas_nulas:
        qtd_nulo = int(qtd * 0.05)
        indices_nulo = np.random.choice(df.index, qtd_nulo, replace=False)
        df.loc[indices_nulo, coluna] = np.nan

    colunas_numericas = [
        'Salário Mensal', 'Anos na Empresa', 'Idade', 'Envolvimento no Trabalho',
        'Aumento Salarial (%)', 'Nível de Opção de Ação', 'Satisfação no Trabalho',
        'Satisfação com o Ambiente de Trabalho', 'Satisfação com Relacionamento no Trabalho',
        'Equilíbrio Vida-Trabalho', 'Distância Casa (km)', 'Avaliação de Desempenho (1-5)',
        'Treinamentos por Ano'
    ]
    for coluna in colunas_numericas:
        qtd_neg = int(qtd * 0.01)
        indices_neg = np.random.choice(df.index, qtd_neg, replace=False)
        df.loc[indices_neg, coluna] *= -1

    variacoes = {
        'Desenvolvedor': ['Desenvolvedor ', 'Dev', 'desenvolvedor'],
        'Cientista de Dados/Data Scientist': ['Cientista de Dados', 'Data Scientist', 'DS']
    }
    for original, alteracoes in variacoes.items():
        indices = df[df['Área de Formação'] == original].sample(frac=0.1, replace=False, random_state=seed).index
        if not indices.empty:
            df.loc[indices, 'Área de Formação'] = np.random.choice(alteracoes, size=len(indices))

    indices_uf = df.sample(frac=0.005, replace=False, random_state=seed).index
    df.loc[indices_uf, 'Estado/UF'] = 'XX'

    indices_outlier_salario = df.sample(frac=0.001, replace=False, random_state=seed).index
    df.loc[indices_outlier_salario, 'Salário Mensal'] = np.random.randint(50000, 100000, size=len(indices_outlier_salario))


    jovens = df[df['Idade'] < 30]
    indices_jovens = jovens.sample(frac=0.001, replace=False, random_state=seed).index
    df.loc[indices_jovens, 'Anos na Empresa'] = df.loc[indices_jovens, 'Idade'] + np.random.randint(5, 15, size=len(indices_jovens))


    indices_cargo = df.sample(frac=0.005, replace=False, random_state=seed).index
    indices_validos = indices_cargo[df.loc[indices_cargo, 'Anos na Empresa'].notna() & (df.loc[indices_cargo, 'Anos na Empresa'] >= 0)]
    df.loc[indices_validos, 'Cargo'] = 'Tempo: ' + (df.loc[indices_validos, 'Anos na Empresa'] + np.random.randint(1, 5, size=len(indices_validos))).astype(str)

    return df

df_funcionarios = gerar_dataframe(qtd=500_00, seed=42)

variaveis_numericas = ['Idade', 'Salário Mensal', 'Distância Casa (km)', 'Satisfação no Trabalho']

for var in variaveis_numericas:
    plt.figure(figsize=(6, 4))
    sns.histplot(df_funcionarios[var], kde=True, color='skyblue')
    plt.title(f'Distribuição de {var}')
    plt.xlabel(var)
    plt.ylabel('Frequência')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Relação entre Attrition e Satisfação
plt.figure(figsize=(6, 4))
sns.boxplot(x='Saiu da Empresa?', y='Satisfação no Trabalho', data=df_funcionarios, palette='Set2')
plt.title("Satisfação no Trabalho por Attrition")
plt.grid(True)
plt.tight_layout()
plt.show()

# Relação entre Attrition e Distância de Casa
plt.figure(figsize=(6, 4))
sns.boxplot(x='Saiu da Empresa?', y='Distância Casa (km)', data=df_funcionarios, palette='Set3')
plt.title("Distância de Casa por Attrition")
plt.grid(True)
plt.tight_layout()
plt.show()

# Distribuição de Attrition (geral)
plt.figure(figsize=(4, 3))
sns.countplot(x='Saiu da Empresa?', data=df_funcionarios, palette='pastel')
plt.title("Distribuição de Attrition")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4-2325731150.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Saiu da Empresa?', y='Satisfação no Trabalho', data=df_funcionarios, palette='Set2')
# /tmp/ipython-input-4-2325731150.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Saiu da Empresa?', y='Distância Casa (km)', data=df_funcionarios, palette='Set3')
# /tmp/ipython-input-4-2325731150.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Saiu da Empresa?', data=df_funcionarios, palette='pastel')

# %%
# Mapa de correlação
plt.figure(figsize=(12, 8))
sns.heatmap(df_funcionarios.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Mapa de Correlação entre Variáveis Numéricas")
plt.tight_layout()
plt.show()

# %%
df_funcionarios.head(150)
# Out:
#      ID Funcionário  Idade     Gênero          Estado Civil  \
# 0                 1     56   Feminino  Prefiro não informar
# 1                 2     46  Masculino         Divorciado(a)
# 2                 3     32   Feminino           Solteiro(a)
# 3                 4     25   Feminino         Divorciado(a)
# 4                 5     38  Masculino             Casado(a)
# ..              ...    ...        ...                   ...
# 145             146     45  Masculino  Prefiro não informar
# 146             147     19  Masculino  Prefiro não informar
# 147             148     59  Masculino             Casado(a)
# 148             149    -23  Masculino             Casado(a)
# 149             150     45  Masculino         Divorciado(a)
#
#              Escolaridade              Cor/Raça                Filhos  \
# 0    Prefiro não informar  Prefiro não informar                   Sim
# 1                     Pós                Branca                   Não
# 2               Doutorado              Indígena  Prefiro não informar
# 3               Graduação                Branca                   Não
# 4                Mestrado              Indígena                   Sim
# ..                    ...                   ...                   ...
# 145             Doutorado                 Parda                   Não
# 146              Mestrado               Amarela                   Não
# 147          Ensino Médio               Amarela                   Sim
# 148  Prefiro não informar                 Preta                   Sim
# 149          Ensino Médio               Amarela                   Não
#
#             Nacionalidade          Naturalidade       Tipo de Moradia  ...  \
# 0             Estrangeira                    SP               Própria  ...
# 1              Brasileira                    RJ         Compartilhada  ...
# 2              Brasileira                    SP  Prefiro não informar  ...
# 3              Brasileira                    MG         Compartilhada  ...
# 4             Estrangeira                    MG  Prefiro não informar  ...
# ..                    ...                   ...                   ...  ...
# 145            Brasileira                    MG               Alugada  ...
# 146            Brasileira                    MG               Alugada  ...
# 147           Estrangeira                    RJ               Alugada  ...
# 148           Estrangeira                    MG  Prefiro não informar  ...
# 149  Prefiro não informar  Prefiro não informar         Compartilhada  ...
#
#     Distância Casa (km) Avaliação de Desempenho (1-5) Treinamentos por Ano  \
# 0                    47                             3                    0
# 1                    31                             3                    3
# 2                    36                             3                    2
# 3                     1                             3                    4
# 4                    30                             3                    3
# ..                  ...                           ...                  ...
# 145                  25                             3                    4
# 146                  26                             3                    0
# 147                  32                             3                    3
# 148                  46                             3                   -2
# 149                  20                             3                    3
#
#     Pretende Mudar de Emprego? Você se vê na empresa em 5 anos?  \
# 0                          Não                              Não
# 1                          Sim             Prefiro não informar
# 2                          Sim             Prefiro não informar
# 3                          Não                              Não
# 4                          Não                              Sim
# ..                         ...                              ...
# 145                        Não             Prefiro não informar
# 146                        Não             Prefiro não informar
# 147                        Sim             Prefiro não informar
# 148                        Não                              Sim
# 149                        Não                              Sim
#
#      Expectativa de Crescimento  Motivo da Mudança de Emprego  \
# 0                         Média  Desenvolvimento profissional
# 1          Prefiro não informar                   Home Office
# 2          Prefiro não informar                 Não responder
# 3                         Média                   Home Office
# 4                         Média          Ambiente de trabalho
# ..                          ...                           ...
# 145                       Baixa                 Não responder
# 146                        Alta                   Home Office
# 147        Prefiro não informar                 Não responder
# 148        Prefiro não informar                   Home Office
# 149                        Alta                       Salário
#
#      Histórico de Afastamentos  Número de Atestados Saiu da Empresa?
# 0                            3                    8              Sim
# 1                            2                    1              Sim
# 2                            0                    5              Sim
# 3                            3                    8              Não
# 4                            3                    9              Não
# ..                         ...                  ...              ...
# 145                          3                    9              Não
# 146                          0                    2              Sim
# 147                          0                    4              Não
# 148                          1                    1              Não
# 149                          0                    6              Não
#
# [150 rows x 39 columns]

# %%
# Ver as primeiras linhas
df_funcionarios.head()

# Ver tipos das colunas e nulos
df_funcionarios.info()

# Estatísticas descritivas
df_funcionarios.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 39 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID Funcionário                             50000 non-null  int64
#  1   Idade                                      50000 non-null  int64
#  2   Gênero                                     50000 non-null  object
#  3   Estado Civil                               50000 non-null  object
#  4   Escolaridade                               50000 non-null  object
#  5   Cor/Raça                                   50000 non-null  object
#  6   Filhos                                     50000 non-null  object
#  7   Nacionalidade                              50000 non-null  object
#  8   Naturalidade                               50000 non-null  object
#  9   Tipo de Moradia                            50000 non-null  object
#  10  PCD                                        50000 non-null  object
#  11  Estado/UF                                  50000 non-null  object
#  12  Área de Formação                           47500 non-null  object
#  13  Departamento                               50000 non-null  object
#  14  Cargo                                      50000 non-null  object
#  15  Envolvimento no Trabalho                   50000 non-null  int64
#  16  Anos na Empresa                            47502 non-null  float64
#  17  Número de Promoções                        50000 non-null  int64
#  18  Salário Mensal                             47504 non-null  float64
#  19  Faixa Salarial                             50000 non-null  category
#  20  Aumento Salarial (%)                       50000 non-null  int64
#  21  Nível de Opção de Ação                     50000 non-null  int64
#  22  Satisfação no Trabalho                     47500 non-null  float64
#  23  Satisfação com o Ambiente de Trabalho      50000 non-null  int64
#  24  Satisfação com Relacionamento no Trabalho  50000 non-null  int64
#  25  Satisfação com os Benefícios               50000 non-null  int64
#  26  Hora Extra                                 50000 non-null  object
#  27  Equilíbrio Vida-Trabalho                   50000 non-null  int64
#  28  Viagem a Negócios                          50000 non-null  object
#  29  Distância Casa (km)                        50000 non-null  int64
#  30  Avaliação de Desempenho (1-5)              50000 non-null  int64
#  31  Treinamentos por Ano                       50000 non-null  int64
#  32  Pretende Mudar de Emprego?                 50000 non-null  object
#  33  Você se vê na empresa em 5 anos?           50000 non-null  object
#  34  Expectativa de Crescimento                 50000 non-null  object
#  35  Motivo da Mudança de Emprego               50000 non-null  object
#  36  Histórico de Afastamentos                  50000 non-null  int64
#  37  Número de Atestados                        50000 non-null  int64
#  38  Saiu da Empresa?                           50000 non-null  category
# dtypes: category(2), float64(3), int64(15), object(19)
# memory usage: 14.2+ MB
#        ID Funcionário        Idade  Envolvimento no Trabalho  Anos na Empresa  \
# count    50000.000000  50000.00000               50000.00000     47502.000000
# mean     25000.500000     37.76528                   2.44588        19.531893
# std      14433.901067     14.25927                   1.22441        12.497871
# min          1.000000    -59.00000                  -4.00000       -40.000000
# 25%      12500.750000     28.00000                   1.00000         9.000000
# 50%      25000.500000     38.00000                   2.00000        20.000000
# 75%      37500.250000     49.00000                   3.00000        30.000000
# max      50000.000000     59.00000                   4.00000        43.000000
#
#        Número de Promoções  Salário Mensal  Aumento Salarial (%)  \
# count         50000.000000    47504.000000          50000.000000
# mean              2.498420    13083.968192             14.162360
# std               1.712243     7560.619853              9.146503
# min               0.000000   -24957.000000            -29.000000
# 25%               1.000000     7203.750000              7.000000
# 50%               2.000000    13163.500000             14.000000
# 75%               4.000000    19169.500000             22.000000
# max               5.000000    95451.000000             29.000000
#
#        Nível de Opção de Ação  Satisfação no Trabalho  \
# count            50000.000000            47500.000000
# mean                 1.473140                2.929874
# std                  1.160907                1.529470
# min                 -3.000000               -5.000000
# 25%                  0.000000                2.000000
# 50%                  1.000000                3.000000
# 75%                  2.000000                4.000000
# max                  3.000000                5.000000
#
#        Satisfação com o Ambiente de Trabalho  \
# count                           50000.000000
# mean                                2.940960
# std                                 1.534654
# min                                -5.000000
# 25%                                 2.000000
# 50%                                 3.000000
# 75%                                 4.000000
# max                                 5.000000
#
#        Satisfação com Relacionamento no Trabalho  \
# count                               50000.000000
# mean                                    2.934880
# std                                     1.533286
# min                                    -5.000000
# 25%                                     2.000000
# 50%                                     3.000000
# 75%                                     4.000000
# max                                     5.000000
#
#        Satisfação com os Benefícios  Equilíbrio Vida-Trabalho  \
# count                  50000.000000              50000.000000
# mean                       2.995660                  2.454300
# std                        1.415444                  1.221974
# min                        1.000000                 -4.000000
# 25%                        2.000000                  1.000000
# 50%                        3.000000                  2.000000
# 75%                        4.000000                  3.000000
# max                        5.000000                  4.000000
#
#        Distância Casa (km)  Avaliação de Desempenho (1-5)  \
# count         50000.000000                   50000.000000
# mean             24.482220                       3.035540
# std              14.986665                       0.684724
# min             -49.000000                      -4.000000
# 25%              12.000000                       3.000000
# 50%              25.000000                       3.000000
# 75%              37.000000                       3.000000
# max              49.000000                       4.000000
#
#        Treinamentos por Ano  Histórico de Afastamentos  Número de Atestados
# count          50000.000000                50000.00000         50000.000000
# mean               2.454340                    1.49514             4.490960
# std                1.776406                    1.11680             2.873716
# min               -5.000000                    0.00000             0.000000
# 25%                1.000000                    0.00000             2.000000
# 50%                2.000000                    1.00000             4.000000
# 75%                4.000000                    2.00000             7.000000
# max                5.000000                    3.00000             9.000000

# %%
df_funcionarios.isnull().sum().sort_values(ascending=False)
# Out:
# Área de Formação                             2500
# Satisfação no Trabalho                       2500
# Anos na Empresa                              2498
# Salário Mensal                               2496
# ID Funcionário                                  0
# Idade                                           0
# Gênero                                          0
# Filhos                                          0
# Cor/Raça                                        0
# Escolaridade                                    0
# Estado Civil                                    0
# PCD                                             0
# Nacionalidade                                   0
# Tipo de Moradia                                 0
# Naturalidade                                    0
# Cargo                                           0
# Departamento                                    0
# Estado/UF                                       0
# Envolvimento no Trabalho                        0
# Número de Promoções                             0
# Faixa Salarial                                  0
# Aumento Salarial (%)                            0
# Nível de Opção de Ação                          0
# Satisfação com o Ambiente de Trabalho           0
# Satisfação com Relacionamento no Trabalho       0
# Satisfação com os Benefícios                    0
# Hora Extra                                      0
# Equilíbrio Vida-Trabalho                        0
# Viagem a Negócios                               0
# Distância Casa (km)                             0
# Avaliação de Desempenho (1-5)                   0
# Treinamentos por Ano                            0
# Pretende Mudar de Emprego?                      0
# Você se vê na empresa em 5 anos?                0
# Expectativa de Crescimento                      0
# Motivo da Mudança de Emprego                    0
# Histórico de Afastamentos                       0
# Número de Atestados                             0
# Saiu da Empresa?                                0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

variaveis_numericas = ['Idade', 'Salário Mensal', 'Distância Casa (km)', 'Satisfação no Trabalho']

for var in variaveis_numericas:
    plt.figure(figsize=(6,4))
    sns.histplot(df_funcionarios[var], kde=True)
    plt.title(f'Distribuição de {var}')
    plt.show()

# %%
# Quantidade de funcionários que saíram vs. ficaram
sns.countplot(x='Saiu da Empresa?', data=df_funcionarios, palette='Set2', hue='Saiu da Empresa?', legend=False)
plt.title("Distribuição de Saída da Empresa")
plt.show()

# Relação entre satisfação e attrition
sns.boxplot(x='Saiu da Empresa?', y='Satisfação no Trabalho', data=df_funcionarios)
plt.title("Satisfação no Trabalho por Saída da Empresa")
plt.show()

# Relação entre distância e attrition
sns.boxplot(x='Saiu da Empresa?', y='Distância Casa (km)', data=df_funcionarios)
plt.title("Distância de Casa por Saída da Empresa")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_funcionarios.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlação entre Variáveis Numéricas")
plt.show()

# %%
display(df_funcionarios.columns)
# Out:
# Index(['ID Funcionário', 'Idade', 'Gênero', 'Estado Civil', 'Escolaridade',
#        'Cor/Raça', 'Filhos', 'Nacionalidade', 'Naturalidade',
#        'Tipo de Moradia', 'PCD', 'Estado/UF', 'Área de Formação',
#        'Departamento', 'Cargo', 'Envolvimento no Trabalho', 'Anos na Empresa',
#        'Número de Promoções', 'Salário Mensal', 'Faixa Salarial',
#        'Aumento Salarial (%)', 'Nível de Opção de Ação',
#        'Satisfação no Trabalho', 'Satisfação com o Ambiente de Trabalho',
#        'Satisfação com Relacionamento no Trabalho',
#        'Satisfação com os Benefícios', 'Hora Extra',
#        'Equilíbrio Vida-Trabalho', 'Viagem a Negócios', 'Distância Casa (km)',
#        'Avaliação de Desempenho (1-5)', 'Treinamentos por Ano',
#        'Pretende Mudar de Emprego?', 'Você se vê na empresa em 5 anos?',
#        'Expectativa de Crescimento', 'Motivo da Mudança de Emprego',
#        'Histórico de Afastamentos', 'Número de Atestados', 'Saiu da Empresa?'],
#       dtype='object')

# %%
def get_genero(row):
    if isinstance(row['Gênero'], str):
        return row['Gênero']
    return 'Não informado'

df_funcionarios['Gênero_plot'] = df_funcionarios.apply(get_genero, axis=1)

plt.figure()
sns.countplot(data=df_funcionarios, x="Gênero_plot", hue="Gênero_plot", palette="pastel", legend=False)
plt.title("Quantidade de pessoas por gênero atuando na empresa")
plt.xlabel("Gênero")
plt.ylabel("Contagem")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df_funcionarios, y="Estado/UF", palette="pastel")
plt.title("Quantidade de profissional por estado")
plt.xlabel("Quantidade")
plt.ylabel("Estado")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-13-2008232638.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_funcionarios, y="Estado/UF", palette="pastel")

# %% [markdown]
# Tratamento de Valores Nulos

# %%
# Visualização de valores nulos

print("\nMapa de valores nulos:")
msno.matrix(df_funcionarios)
plt.title('Matriz de Valores Nulos')
plt.show()

print("\nContagem de valores nulos por coluna:\n")
print(df_funcionarios.isnull().sum().sort_values(ascending=False))
# Out:
# Mapa de valores nulos:
# Contagem de valores nulos por coluna:
#
# Satisfação no Trabalho                       2500
# Área de Formação                             2500
# Anos na Empresa                              2498
# Salário Mensal                               2496
# ID Funcionário                                  0
# Idade                                           0
# Gênero                                          0
# Estado Civil                                    0
# Nacionalidade                                   0
# Filhos                                          0
# Cor/Raça                                        0
# Escolaridade                                    0
# Estado/UF                                       0
# Naturalidade                                    0
# PCD                                             0
# Tipo de Moradia                                 0
# Envolvimento no Trabalho                        0
# Cargo                                           0
# Departamento                                    0
# Número de Promoções                             0
# Faixa Salarial                                  0
# Aumento Salarial (%)                            0
# Nível de Opção de Ação                          0
# Satisfação com o Ambiente de Trabalho           0
# Satisfação com Relacionamento no Trabalho       0
# Satisfação com os Benefícios                    0
# Hora Extra                                      0
# Equilíbrio Vida-Trabalho                        0
# Viagem a Negócios                               0
# Distância Casa (km)                             0
# Avaliação de Desempenho (1-5)                   0
# Treinamentos por Ano                            0
# Pretende Mudar de Emprego?                      0
# Você se vê na empresa em 5 anos?                0
# Expectativa de Crescimento                      0
# Motivo da Mudança de Emprego                    0
# Histórico de Afastamentos                       0
# Número de Atestados                             0
# Saiu da Empresa?                                0
# Gênero_plot                                     0
# dtype: int64

# %%
# Imputação para colunas numéricas

df_funcionarios['Salário Mensal'].fillna(df_funcionarios['Salário Mensal'].median(), inplace=True)
# Out:
# /tmp/ipython-input-49-2271400505.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_funcionarios['Salário Mensal'].fillna(df_funcionarios['Salário Mensal'].median(), inplace=True)

# %%
# Imputando mediana

df_funcionarios['Anos na Empresa'].fillna(df_funcionarios['Anos na Empresa'].median(), inplace=True)
# Out:
# /tmp/ipython-input-15-3191291079.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_funcionarios['Anos na Empresa'].fillna(df_funcionarios['Anos na Empresa'].median(), inplace=True)

# %%
# Imputação para colunas categóricas

df_funcionarios['Área de Formação'].fillna(df_funcionarios['Área de Formação'].mode()[0], inplace=True)
df_funcionarios['Satisfação no Trabalho'].fillna(df_funcionarios['Satisfação no Trabalho'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-16-65409876.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_funcionarios['Área de Formação'].fillna(df_funcionarios['Área de Formação'].mode()[0], inplace=True)
# /tmp/ipython-input-16-65409876.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_funcionarios['Satisfação no Trabalho'].fillna(df_funcionarios['Satisfação no Trabalho'].mode()[0], inplace=True)

# %%
# Verificar nulos após a imputação

print("\nContagem de valores nulos após imputação:")
print(df_funcionarios.isnull().sum().sort_values(ascending=False))
# Out:
# Contagem de valores nulos após imputação:
# Salário Mensal                               2496
# ID Funcionário                                  0
# Gênero                                          0
# Idade                                           0
# Escolaridade                                    0
# Cor/Raça                                        0
# Filhos                                          0
# Estado Civil                                    0
# Nacionalidade                                   0
# Naturalidade                                    0
# PCD                                             0
# Tipo de Moradia                                 0
# Área de Formação                                0
# Departamento                                    0
# Cargo                                           0
# Estado/UF                                       0
# Envolvimento no Trabalho                        0
# Anos na Empresa                                 0
# Número de Promoções                             0
# Faixa Salarial                                  0
# Aumento Salarial (%)                            0
# Nível de Opção de Ação                          0
# Satisfação no Trabalho                          0
# Satisfação com o Ambiente de Trabalho           0
# Satisfação com Relacionamento no Trabalho       0
# Satisfação com os Benefícios                    0
# Hora Extra                                      0
# Equilíbrio Vida-Trabalho                        0
# Viagem a Negócios                               0
# Distância Casa (km)                             0
# Avaliação de Desempenho (1-5)                   0
# Treinamentos por Ano                            0
# Pretende Mudar de Emprego?                      0
# Você se vê na empresa em 5 anos?                0
# Expectativa de Crescimento                      0
# Motivo da Mudança de Emprego                    0
# Histórico de Afastamentos                       0
# Número de Atestados                             0
# Saiu da Empresa?                                0
# Gênero_plot                                     0
# dtype: int64

# %% [markdown]
# Tratamento de Valores Negativos e Outliers

# %%
# Tratar valores negativos

numeric_cols_to_check_neg = ['Salário Mensal', 'Anos na Empresa', 'Idade', 'NívelCargo',
                             'Envolvimento Trabalho', 'Aumento Salarial', 'Nível Opção Ação',
                             'Satisfaçã Trabalho', 'Satisfação Ambiente', 'Satisfação Relacionamento',
                             'Equilíbrio Vida Trabalho', 'Distância de Casa', 'Avaliação de sempenho',
                             'Treinamentos Ano']

for col in numeric_cols_to_check_neg:
    if col in df_funcionarios.columns:
        df_funcionarios[col] = np.where(df_funcionarios[col] < 0, np.nan, df_funcionarios[col])

        # Depois de substituir por NaN imputar com a mediana

        df_funcionarios[col].fillna(df_funcionarios[col].median(), inplace=True)
# Out:
# /tmp/ipython-input-18-1418917177.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_funcionarios[col].fillna(df_funcionarios[col].median(), inplace=True)

# %%
# Limitação por IQR para Salário Mensal

Q1 = df_funcionarios['Salário Mensal'].quantile(0.25)
Q3 = df_funcionarios['Salário Mensal'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Substituir outliers por limites

df_funcionarios['Salário Mensal'] = np.where(df_funcionarios['Salário Mensal'] > upper_bound, upper_bound,
                               np.where(df_funcionarios['Salário Mensal'] < lower_bound, lower_bound, df_funcionarios['Salário Mensal']))

print("\nEstatísticas Descritivas Salário Mensal após tratamento de Outliers:\n")

print(df_funcionarios['Salário Mensal'].describe())
# Out:
# Estatísticas Descritivas Salário Mensal após tratamento de Outliers:
#
# count    50000.000000
# mean     13298.907600
# std       6626.137799
# min       1500.000000
# 25%       7765.000000
# 50%      13280.000000
# 75%      18852.000000
# max      35482.500000
# Name: Salário Mensal, dtype: float64

# %%
if df_funcionarios['Salário Mensal'].notna().any():
	df_funcionarios['Salário Mensal'] = df_funcionarios['Salário Mensal'].fillna(df_funcionarios['Salário Mensal'].mean())

if df_funcionarios['Anos na Empresa'].notna().any():
	df_funcionarios['Anos na Empresa'] = df_funcionarios['Anos na Empresa'].fillna(df_funcionarios['Anos na Empresa'].median())

moda_area = df_funcionarios['Área de Formação'].mode()
if not moda_area.empty:
	df_funcionarios['Área de Formação'] = df_funcionarios['Área de Formação'].fillna(moda_area[0])

# %%
sns.boxplot(data=df_funcionarios, x='Salário Mensal')
plt.title("Boxplot de Salário Mensal")
plt.show()

# Remover outliers acima de 3 desvios padrão
media = df_funcionarios['Salário Mensal'].mean()
desvio = df_funcionarios['Salário Mensal'].std()
limite_superior = media + 3 * desvio
df_funcionarios = df_funcionarios[df_funcionarios['Salário Mensal'] <= limite_superior]

# %%
# Calcular a média de salário por idade
salario_por_idade = df_funcionarios.groupby('Idade')['Salário Mensal'].mean()

fig = px.line( salario_por_idade.reset_index(), x = "Idade", y = "Salário Mensal", title = "Média de salário por idade", markers = True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c22288ac-ea2a-4a55-8d3d-f6f53c77c688" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c22288ac-ea2a-4a55-8d3d-f6f53c77c688")) {                    Plotly.newPlot(                        "c22288ac-ea2a-4a55-8d3d-f6f53c77c688",                        [{"hovertemplate":"Idade=%{x}\u003cbr\u003eSalário Mensal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[18.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0,30.0,31.0,32.0,33.0,34.0,35.0,36.0,37.0,38.0,39.0,40.0,41.0,42.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,50.0,51.0,52.0,53.0,54.0,55.0,56.0,57.0,58.0,59.0],"xaxis":"x","y":[13347.962864721485,12923.326565143823,13297.135823429542,13352.620116375727,13235.464837049743,13179.58849557522,13224.042387543253,13394.605020920502,13145.09090909091,13342.253994953742,13380.797900262467,13523.657848324516,13175.851080864692,13503.544736842105,13137.53839732888,13245.781276595744,13432.983372921615,12961.38655462185,13405.514705882353,13443.950747581355,13444.222876366695,13250.918934911242,13321.27958697379,13337.214646464647,13127.454545454546,13166.383495145632,13120.861135371179,13318.728536385936,13260.236019736842,13606.562814070352,13337.762367491167,13168.040587219344,12853.818019625334,13737.060954063605,13373.167992926614,13017.989256198347,13055.370719178081,13230.720891824938,13126.5,13097.175043327556,13586.494477485132,13452.203826955076],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewid ...

# %%
df_funcionarios['Salário Mensal'].describe()
# Out:
# count    49950.000000
# mean     13276.701802
# std       6592.157865
# min       1500.000000
# 25%       7758.250000
# 50%      13280.000000
# 75%      18826.000000
# max      24999.000000
# Name: Salário Mensal, dtype: float64

# %% [markdown]
#  Tratamento de valores inválidos

# %%
# Tratamento de Inconsistências em Colunas Categóricas

df_funcionarios['Área de Formação'] = df_funcionarios['Área de Formação'].replace({
    'Desenvolvedor ': 'Desenvolvedor',
    'Dev': 'Desenvolvedor',
    'desenvolvedor': 'Desenvolvedor',
    'Cientista de Dados': 'Cientista de Dados/Data Scientist',
    'Data Scientist': 'Cientista de Dados/Data Scientist',
    'DS': 'Cientista de Dados/Data Scientist'
})

# Substituir 'XX' por NaN na coluna correta
df_funcionarios['Estado/UF'] = df_funcionarios['Estado/UF'].replace('XX', np.nan)

# Imputar com a moda
df_funcionarios['Estado/UF'].fillna(df_funcionarios['Estado/UF'].mode()[0], inplace=True)

print("\nContagem de valores únicos em Área de Formação após padronização:\n")
print(df_funcionarios['Área de Formação'].value_counts())

print("\nContagem de valores únicos em Estado/UF após tratamento:\n")
print(df_funcionarios['Estado/UF'].value_counts())
# Out:
# Contagem de valores únicos em Área de Formação após padronização:
#
# Área de Formação
# Marketing                            5773
# Administrativo                       3258
# UX/UI                                3226
# Engenharia de Dados/Data Engineer    3218
# Suporte Técnico                      3197
# RH                                   3181
# Pesquisa e Desenvolvimento           3169
# Vendas                               3163
# Cientista de Dados/Data Scientist    3134
# Prefiro não informar                 3130
# Financeiro                           3125
# Desenvolvedor                        3114
# Engenharia de Software               3101
# Analista de Dados/Data Analyst       3084
# Product Manager/PO                   3077
# Name: count, dtype: int64
#
# Contagem de valores únicos em Estado/UF após tratamento:
#
# Estado/UF
# SP               3628
# AM               3386
# CE               3352
# MG               3338
# PE               3333
# BA               3320
# RJ               3312
#                  3306
# MT               3303
# SC               3295
# AL               3289
# DF               3284
# RS               3282
# PR               3278
# Não informado    3244
# Name: count, dtype: int64
# /tmp/ipython-input-25-638374018.py:16: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Transformações - Criar coluna Idade Categoria

bins_idade = [0, 25, 35, 45, 55, np.inf]
labels_idade = ['Jovem', 'Adulto Jovem', 'Adulto', 'Adulto Maduro', 'Idoso']
df_funcionarios['Idade Categoria'] = pd.cut(df_funcionarios['Idade'], bins=bins_idade, labels=labels_idade, right=False)

# %%
df_funcionarios.columns
# Out:
# Index(['ID Funcionário', 'Idade', 'Gênero', 'Estado Civil', 'Escolaridade',
#        'Cor/Raça', 'Filhos', 'Nacionalidade', 'Naturalidade',
#        'Tipo de Moradia', 'PCD', 'Estado/UF', 'Área de Formação',
#        'Departamento', 'Cargo', 'Envolvimento no Trabalho', 'Anos na Empresa',
#        'Número de Promoções', 'Salário Mensal', 'Faixa Salarial',
#        'Aumento Salarial (%)', 'Nível de Opção de Ação',
#        'Satisfação no Trabalho', 'Satisfação com o Ambiente de Trabalho',
#        'Satisfação com Relacionamento no Trabalho',
#        'Satisfação com os Benefícios', 'Hora Extra',
#        'Equilíbrio Vida-Trabalho', 'Viagem a Negócios', 'Distância Casa (km)',
#        'Avaliação de Desempenho (1-5)', 'Treinamentos por Ano',
#        'Pretende Mudar de Emprego?', 'Você se vê na empresa em 5 anos?',
#        'Expectativa de Crescimento', 'Motivo da Mudança de Emprego',
#        'Histórico de Afastamentos', 'Número de Atestados', 'Saiu da Empresa?',
#        'Gênero_plot', 'Idade Categoria'],
#       dtype='object')

# %%
# Transformar colunas categóricas para análise/modelagem

# df_funcionarios = pd.get_dummies(df_funcionarios, columns=['Gênero'], prefix='Genero', dummy_na=False)

# %%
# Label Encoding - 'Saiu da Empresa?'

le = LabelEncoder()
df_funcionarios['SaiuDaEmpresa_Encoded'] = le.fit_transform(df_funcionarios['Saiu da Empresa?'])

print("\nPrimeiras 5 linhas após Engenharia de Features:")
print(df_funcionarios.head())
# Out:
# Primeiras 5 linhas após Engenharia de Features:
#    ID Funcionário  Idade     Gênero          Estado Civil  \
# 0               1   56.0   Feminino  Prefiro não informar
# 1               2   46.0  Masculino         Divorciado(a)
# 2               3   32.0   Feminino           Solteiro(a)
# 3               4   25.0   Feminino         Divorciado(a)
# 4               5   38.0  Masculino             Casado(a)
#
#            Escolaridade              Cor/Raça                Filhos  \
# 0  Prefiro não informar  Prefiro não informar                   Sim
# 1                   Pós                Branca                   Não
# 2             Doutorado              Indígena  Prefiro não informar
# 3             Graduação                Branca                   Não
# 4              Mestrado              Indígena                   Sim
#
#   Nacionalidade Naturalidade       Tipo de Moradia  ...  \
# 0   Estrangeira           SP               Própria  ...
# 1    Brasileira           RJ         Compartilhada  ...
# 2    Brasileira           SP  Prefiro não informar  ...
# 3    Brasileira           MG         Compartilhada  ...
# 4   Estrangeira           MG  Prefiro não informar  ...
#
#   Pretende Mudar de Emprego? Você se vê na empresa em 5 anos?  \
# 0                        Não                              Não
# 1                        Sim             Prefiro não informar
# 2                        Sim             Prefiro não informar
# 3                        Não                              Não
# 4                        Não                              Sim
#
#   Expectativa de Crescimento  Motivo da Mudança de Emprego  \
# 0                      Média  Desenvolvimento profissional
# 1       Prefiro não informar                   Home Office
# 2       Prefiro não informar                 Não responder
# 3                      Média                   Home Office
# 4                      Média          Ambiente de trabalho
#
#   Histórico de Afastamentos  Número de Atestados  Saiu da Empresa?  \
# 0                         3                    8               Sim
# 1                         2                    1               Sim
# 2                         0                    5               Sim
# 3                         3                    8               Não
# 4                         3                    9               Não
#
#    Gênero_plot  Idade Categoria SaiuDaEmpresa_Encoded
# 0     Feminino            Idoso                     1
# 1    Masculino    Adulto Maduro                     1
# 2     Feminino     Adulto Jovem                     1
# 3     Feminino     Adulto Jovem                     0
# 4    Masculino           Adulto                     0
#
# [5 rows x 42 columns]

# %%
# Dados tratados

plt.figure(figsize=(8, 6))
sns.countplot(data=df_funcionarios, x='Idade Categoria', order=df_funcionarios['Idade Categoria'].value_counts().index)
plt.title('Distribuição da Idade por Categoria')
plt.xlabel('Categoria de Idade')
plt.ylabel('Número de Funcionários')
plt.show()

# %%
colunas = ['Salário Mensal', 'Distância Casa (km)']

for col in colunas:
    if col in df_funcionarios.columns:
        if df_funcionarios[col].dropna().empty:
            print(f"A coluna '{col}' está vazia ou só tem NaNs.")
        elif not np.issubdtype(df_funcionarios[col].dtype, np.number):
            print(f"A coluna '{col}' não é numérica.")
        else:
            mediana = df_funcionarios[col].median()
            df_funcionarios[col].fillna(mediana, inplace=True)
    else:
        print(f"A coluna '{col}' não existe no DataFrame.")

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
if df_funcionarios['Salário Mensal'].dropna().empty:
    plt.text(0.5, 0.5, 'Sem dados válidos', ha='center', va='center', fontsize=12)
    plt.title('Box Plot - Salário Mensal')
    plt.axis('off')
else:
    sns.boxplot(x=df_funcionarios['Salário Mensal'])
    plt.title('Box Plot - Salário Mensal')

plt.subplot(1, 2, 2)
if df_funcionarios['Distância Casa (km)'].dropna().empty:
    plt.text(0.5, 0.5, 'Sem dados válidos', ha='center', va='center', fontsize=12)
    plt.title('Box Plot - Distância da Casa')
    plt.axis('off')
else:
    sns.boxplot(x=df_funcionarios['Distância Casa (km)'])
    plt.title('Box Plot - Distância da Casa')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-31-4156626352.py:11: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Target de distribuição de Saída da Empresa

plt.figure(figsize=(6, 4))
sns.countplot(data=df_funcionarios, x='Saiu da Empresa?')
plt.title('Distribuição da Variável (Saiu da Empresa)')
plt.xlabel('Saiu da Empresa')
plt.ylabel('Número de Funcionários')
plt.show()

# %%
# Relação entre Salário Mensal e Saiu da Empresa

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_funcionarios, x='Saiu da Empresa?', y='Salário Mensal')
plt.title('Salário Mensal por Status de Saída da Empresa')
plt.xlabel('Saiu da Empresa?')
plt.ylabel('Salário Mensal')
plt.show()

# %%
# Análise de Saída da Empresa por Gênero

plt.figure(figsize=(8, 6))
sns.countplot(data=df_funcionarios, x='Gênero_plot', hue='Saiu da Empresa?')
plt.title('Saída da Empresa por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Número de Funcionários')
plt.show()

# %%
# Plotly (interativo)
fig = px.histogram(df_funcionarios, x='Departamento', color='Saiu da Empresa?', title='Saída da Empresa por Departamento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d7c1946b-8297-4398-8c9c-8c714511a2e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7c1946b-8297-4398-8c9c-8c714511a2e5")) {                    Plotly.newPlot(                        "d7c1946b-8297-4398-8c9c-8c714511a2e5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Saiu da Empresa?=Sim\u003cbr\u003eDepartamento=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sim","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sim","offsetgroup":"Sim","orientation":"v","showlegend":true,"x":["Administrativo","Vendas","Negócio","TI","Negócio","Negócio","Pesquisa","TI","RH","RH","TI","TI","TI","Negócio","Negócio","Pesquisa","Vendas","Vendas","RH","Pesquisa","Pesquisa","RH","Administrativo","Administrativo","Administrativo","Vendas","Negócio","Pesquisa","Negócio","Vendas","Negócio","Administrativo","Vendas","TI","RH","TI","RH","TI","Administrativo","Administrativo","Vendas","Administrativo","Pesquisa","Administrativo","Vendas","Administrativo","Administrativo","Pesquisa","Vendas","Vendas","TI","RH","Administrativo","Pesquisa","Negócio","Administrativo","Vendas","RH","Negócio","Administrativo","RH","Administrativo","Vendas","Pesquisa","RH","Pesquisa","Administrativo","Vendas","Vendas","RH","Pesquisa","RH","Negócio","Administrativo","Pesquisa","RH","Administrativo","TI","Vendas","Vendas","Negócio","Vendas","Vendas","TI","TI","Administrativo","Pesquisa","Administrativo","Negócio","Pesquisa","Pesquisa","Pesquisa","Pesquisa","Administrativo","Administrativo","TI","RH","Vendas","Vendas","TI","RH","Pesquisa","Vendas","Pesquisa","Vendas","TI","Pesquisa","RH","Negócio","RH","Vendas","RH","Vendas","TI","Negócio","TI","TI","Administrativo","RH","Pesquisa","Negócio","Vendas","TI","Negócio","Pesquisa","RH","Negócio","TI","Vendas","TI","RH","TI","Administrativo","TI","Vendas","Administrativo","TI","TI","Administrativo","Negócio","Administrativo","Vendas","Negócio","Vendas","Administrativo","RH","Vendas","Vendas","RH","Negócio","Negócio","Vendas","Pesquisa","Administrativo","Pesquisa","RH","Vendas","RH","TI","TI","Pesquisa","RH","Pesquisa","TI","Negócio","TI","RH","Pesquisa","Negócio","Administrativo","Pesquisa","Pesquisa","Negócio","Vendas","TI","Negócio","Administrativo","Pesquisa","Vendas","Vendas","Vendas","TI","Pesquisa","Negócio","RH","Vendas","Negócio","Negócio","RH","TI","RH","Administrativo","Pesquisa","RH","Vendas","RH","TI","Negócio","Vendas","Negócio","RH","TI","Pesquisa","Pesquisa","Pesquisa","TI","Negócio","Administrativo","Administrativo","RH","Administrativo","TI","Negócio","Administrativo","Negócio","Vendas","Administrativo","Pesquisa","TI","Negócio","Negócio","Pesquisa","Vendas","TI","Administrativo","RH","Negócio","Vendas","Vendas","Vendas","Administrativo","Vendas","Administrativo","Negócio","RH","TI","Administrativo","RH","Vendas","TI","Vendas","Pesquisa","RH","RH","TI","Negócio","RH","Administrativo","RH","TI","Negócio","Negócio","Pesquisa","TI","Negócio","Negócio","Pesquisa","Negócio","Pesquisa","RH","Negócio","Negócio","RH","RH","Pesquisa","Vendas","Administrativo","Vendas","Administrativo","Vendas","RH","Negócio","Administrativo","Pesquisa","TI","TI","TI","Vendas","Pesquisa","Negócio","Negócio","Negócio","Administrativo","Negócio","Negócio","Vendas","Pesquisa","Negócio","RH","Administrativo","Administrativo","Administrativo","Administrativo","RH","Negócio","TI","Negócio","Negócio","RH","Pesquisa","Vendas","Vendas","RH","Negócio","Pesquisa","Vendas","RH","TI","Pesquisa","RH","Pesquisa","Pesquisa","Pesquisa","Negócio","TI","Negócio","Negócio","Administrativo","Negócio","TI","RH","Negócio","Pesquisa","RH","Vendas","TI","RH","Pesquisa","TI","Ve ...

# %%
df_funcionarios.to_csv("dados_funcionarios.csv", index=False)

# %%
print("\nDataFrame final após tratamento:")
df_funcionarios.info()
print(df_funcionarios.head())
# Out:
# DataFrame final após tratamento:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49950 entries, 0 to 49999
# Data columns (total 42 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID Funcionário                             49950 non-null  int64
#  1   Idade                                      49950 non-null  float64
#  2   Gênero                                     49950 non-null  object
#  3   Estado Civil                               49950 non-null  object
#  4   Escolaridade                               49950 non-null  object
#  5   Cor/Raça                                   49950 non-null  object
#  6   Filhos                                     49950 non-null  object
#  7   Nacionalidade                              49950 non-null  object
#  8   Naturalidade                               49950 non-null  object
#  9   Tipo de Moradia                            49950 non-null  object
#  10  PCD                                        49950 non-null  object
#  11  Estado/UF                                  49950 non-null  object
#  12  Área de Formação                           49950 non-null  object
#  13  Departamento                               49950 non-null  object
#  14  Cargo                                      49950 non-null  object
#  15  Envolvimento no Trabalho                   49950 non-null  int64
#  16  Anos na Empresa                            49950 non-null  float64
#  17  Número de Promoções                        49950 non-null  int64
#  18  Salário Mensal                             49950 non-null  float64
#  19  Faixa Salarial                             49950 non-null  category
#  20  Aumento Salarial (%)                       49950 non-null  int64
#  21  Nível de Opção de Ação                     49950 non-null  int64
#  22  Satisfação no Trabalho                     49950 non-null  float64
#  23  Satisfação com o Ambiente de Trabalho      49950 non-null  int64
#  24  Satisfação com Relacionamento no Trabalho  49950 non-null  int64
#  25  Satisfação com os Benefícios               49950 non-null  int64
#  26  Hora Extra                                 49950 non-null  object
#  27  Equilíbrio Vida-Trabalho                   49950 non-null  int64
#  28  Viagem a Negócios                          49950 non-null  object
#  29  Distância Casa (km)                        49950 non-null  int64
#  30  Avaliação de Desempenho (1-5)              49950 non-null  int64
#  31  Treinamentos por Ano                       49950 non-null  int64
#  32  Pretende Mudar de Emprego?                 49950 non-null  object
#  33  Você se vê na empresa em 5 anos?           49950 non-null  object
#  34  Expectativa de Crescimento                 49950 non-null  object
#  35  Motivo da Mudança de Emprego               49950 non-null  object
#  36  Histórico de Afastamentos                  49950 non-null  int64
#  37  Número de Atestados                        49950 non-null  int64
#  38  Saiu da Empresa?                           49950 non-null  category
#  39  Gênero_plot                                49950 non-null  object
#  40  Idade Categoria                            49950 non-null  category
#  41  SaiuDaEmpresa_Encoded                      49950 non-null  int64
# dtypes: category(3), float64(4), int64(15), object(20)
# memory usage: 15.4+ MB
#    ID Funcionário  Idade     Gênero          Estado Civil  \
# 0               1   56.0   Feminino  Prefiro não informar
# 1               2   46.0  Masculino         Divorciado(a)
# 2               3   32.0   Feminino           Solteiro(a)
# 3               4   25.0   Feminino         Divorciado(a)
# 4               5   38.0  Masculino             Casado(a)
#
#            Escolaridade              Cor/Raça                Filhos  \
# 0  Prefiro não informar  Prefiro não informar                   Sim
# 1                   Pós                Branca                   Não
# 2             Doutorado              Indígena  Prefiro não informar
# 3             Graduação                Branca                   Não
# 4              Mestrado              Indígena                   Sim
#
#   Nacionalidade Naturalidade       Tipo de Moradia  ...  \
# 0   Estrangeira           SP               Própria  ...
# 1    Brasileira           RJ         Compartilhada  ...
# 2    Brasileira           SP  Prefiro não informar  ...
# 3    Brasileira           MG         Compartilhada  ...
# 4   Estrangeira           MG  Prefiro não informar  ...
#
#   Pretende Mudar de Emprego? Você se vê na empresa em 5 anos?  \
# 0                        Não                              Não
# 1                        Sim             Prefiro não informar
# 2                        Sim             Prefiro não informar
# 3                        Não                              Não
# 4                        Não                              Sim
#
#   Expectativa de Crescimento  Motivo da Mudança de Emprego  \
# 0                      Média  Desenvolvimento profissional
# 1       Prefiro não informar                   Home Office
# 2       Prefiro não informar                 Não responder
# 3                      Média                   Home Office
# 4                      Média          Ambiente de trabalho
#
#   Histórico de Afastamentos  Número de Atestados  Saiu da Empresa?  \
# 0                         3                    8               Sim
# 1                         2                    1               Sim
# 2                         0                    5               Sim
# 3                         3                    8               Não
# 4                         3                    9               Não
#
#    Gênero_plot  Idade Categoria SaiuDaEmpresa_Encoded
# 0     Feminino            Idoso                     1
# 1    Masculino    Adulto Maduro                     1
# 2     Feminino     Adulto Jovem                     1
# 3     Feminino     Adulto Jovem                     0
# 4    Masculino           Adulto                     0
#
# [5 rows x 42 columns]

# %%
# Feature Engineering

# 1. Salário Anual
df_funcionarios['SalarioAnual'] = df_funcionarios['Salário Mensal'] * 12

# 2. Satisfação Média Geral
df_funcionarios['SatisfacaoMedia'] = (
    df_funcionarios['Satisfação no Trabalho'] +
    df_funcionarios['Satisfação com o Ambiente de Trabalho'] +
    df_funcionarios['Satisfação com Relacionamento no Trabalho']
) / 3

# 3. Distância Alta (binária)
df_funcionarios['Distancia_Alta'] = df_funcionarios['Distância Casa (km)'].apply(lambda x: 1 if x > 20 else 0)

# 4. Satisfação Baixa
df_funcionarios['Satisfacao_Baixa'] = df_funcionarios['Satisfação no Trabalho'].apply(lambda x: 1 if x <= 2 else 0)

# 5. Engajamento Geral
df_funcionarios['EngajamentoGeral'] = (
    df_funcionarios['Envolvimento no Trabalho'] +
    df_funcionarios['Satisfação no Trabalho']
)

# 6. Idade em Categorias
df_funcionarios['Idade_Categoria'] = pd.cut(
    df_funcionarios['Idade'],
    bins=[17, 25, 35, 50, 100],
    labels=['Jovem', 'Adulto', 'Meia-idade', 'Sênior']
)

display(df_funcionarios.head())
# Out:
#    ID Funcionário  Idade     Gênero          Estado Civil  \
# 0               1     56   Feminino  Prefiro não informar
# 1               2     46  Masculino         Divorciado(a)
# 2               3     32   Feminino           Solteiro(a)
# 3               4     25   Feminino         Divorciado(a)
# 4               5     38  Masculino             Casado(a)
#
#            Escolaridade              Cor/Raça                Filhos  \
# 0  Prefiro não informar  Prefiro não informar                   Sim
# 1                   Pós                Branca                   Não
# 2             Doutorado              Indígena  Prefiro não informar
# 3             Graduação                Branca                   Não
# 4              Mestrado              Indígena                   Sim
#
#   Nacionalidade Naturalidade       Tipo de Moradia  ...  \
# 0   Estrangeira           SP               Própria  ...
# 1    Brasileira           RJ         Compartilhada  ...
# 2    Brasileira           SP  Prefiro não informar  ...
# 3    Brasileira           MG         Compartilhada  ...
# 4   Estrangeira           MG  Prefiro não informar  ...
#
#    Motivo da Mudança de Emprego Histórico de Afastamentos Número de Atestados  \
# 0  Desenvolvimento profissional                         3                   8
# 1                   Home Office                         2                   1
# 2                 Não responder                         0                   5
# 3                   Home Office                         3                   8
# 4          Ambiente de trabalho                         3                   9
#
#   Saiu da Empresa? SalarioAnual  SatisfacaoMedia  Distancia_Alta  \
# 0              Sim      97644.0         4.333333               1
# 1              Sim      96900.0         2.333333               1
# 2              Sim      95532.0         2.333333               1
# 3              Não     299208.0         3.333333               0
# 4              Não     179208.0         2.666667               1
#
#    Satisfacao_Baixa  EngajamentoGeral Idade_Categoria
# 0                 0               4.0          Sênior
# 1                 0               6.0      Meia-idade
# 2                 0               8.0          Adulto
# 3                 1               5.0           Jovem
# 4                 1               5.0      Meia-idade
#
# [5 rows x 45 columns]
